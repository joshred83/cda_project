# %%
# libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import data scientist data
data_scientists = pd.read_csv('bls_all_data_M_2022_industry.csv')

# %%
# inspect data
display(data_scientists.head())
print(data_scientists.columns)
print(len(data_scientists))
print("")
# Out:
#    AREA AREA_TITLE  AREA_TYPE PRIM_STATE   NAICS  \
# 0    99       U.S.          1         US  000000
# 1    99       U.S.          1         US  000001
# 2    99       U.S.          1         US      21
# 3    99       U.S.          1         US      22
# 4    99       U.S.          1         US      23
#
#                                      NAICS_TITLE                    I_GROUP  \
# 0                                 Cross-industry             cross-industry
# 1         Cross-industry, private ownership only  cross-industry, ownership
# 2  Mining, Quarrying, and Oil and Gas Extraction                     sector
# 3                                      Utilities                     sector
# 4                                   Construction                     sector
#
#    OWN_CODE OCC_CODE        OCC_TITLE  ... H_MEDIAN H_PCT75 H_PCT90  A_PCT10  \
# 0      1235  15-2051  Data Scientists  ...    49.76   65.68   84.03    58510
# ...

# %%
# import all data
sheet_name = 'All May 2022 data'
all_data_filtered = pd.read_excel('all_data_M_2022.xlsx', sheet_name=sheet_name)
# filter so that only industry US level data
all_data_filtered = all_data_filtered[all_data_filtered['AREA_TYPE'] == 1]

# %%
# inspect
display(all_data_filtered.head())
print(all_data_filtered.columns)
print(len(all_data_filtered))
# Out:
#    AREA AREA_TITLE  AREA_TYPE PRIM_STATE   NAICS     NAICS_TITLE  \
# 0    99       U.S.          1         US  000000  Cross-industry
# 1    99       U.S.          1         US  000000  Cross-industry
# 2    99       U.S.          1         US  000000  Cross-industry
# 3    99       U.S.          1         US  000000  Cross-industry
# 4    99       U.S.          1         US  000000  Cross-industry
#
#           I_GROUP  OWN_CODE OCC_CODE               OCC_TITLE  ... H_MEDIAN  \
# 0  cross-industry      1235  00-0000         All Occupations  ...    22.26
# 1  cross-industry      1235  11-0000  Management Occupations  ...    51.62
# 2  cross-industry      1235  11-1000          Top Executives  ...    48.02
# 3  cross-industry      1235  11-1010        Chief Executives  ...    91.12
# 4  cross-industry      1235  11-1011        Chief Executives  ...    91.12
#
#   H_PCT75 H_PCT90 A_PCT10 A_PCT25 A_MEDIAN A_PCT75 A_PCT90 ANNUAL HOURLY
# ...

# %%
all_data_filtered['OWN_CODE'].unique()
# Out:
# array([1235,    5,  235,   58,   57,  123,    1,    2,    3,   59])

# %%
print(len(all_data_filtered['NAICS_TITLE'].unique()))
# print(data['NAICS_TITLE'].unique())

# %%
len(data)

# %%
print(len(data['NAICS'].unique()))

# %%
# convert columns to numeric
columns_to_convert = ['TOT_EMP',
       'EMP_PRSE', 'JOBS_1000', 'LOC_QUOTIENT', 'PCT_TOTAL', 'PCT_RPT',
       'H_MEAN', 'A_MEAN', 'MEAN_PRSE', 'H_PCT10', 'H_PCT25', 'H_MEDIAN',
       'H_PCT75', 'H_PCT90', 'A_PCT10', 'A_PCT25', 'A_MEDIAN', 'A_PCT75',
       'A_PCT90', 'ANNUAL', 'HOURLY']

data[columns_to_convert] = data[columns_to_convert].apply(pd.to_numeric, errors='coerce')

# %%
# columns that are numeric
numeric_columns = []

# Iterate through columns and check if they have numeric data type
for column in data.columns:
    if pd.api.types.is_numeric_dtype(data[column]):
        numeric_columns.append(column)

# Print the list of numeric columns
print("Numeric columns:", numeric_columns)

# %%
# correlation_matrix = data[numeric_columns].corr()
# fig, ax = plt.subplots(figsize=(12, 12))
# sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", ax=ax)
