# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import ElasticNet, ElasticNetCV, Lasso, LassoCV, Ridge, RidgeCV
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline
import numpy as np

# %%
# Loaded variable 'df' from URI: /home/red/cda_project-1/data/salaries.csv

df = pd.read_csv(r"data/salaries.csv")

# %%
xdf = pd.get_dummies(df.select_dtypes("object"), drop_first = True)

# %%
xdf = pd.concat([df.select_dtypes(exclude="object"), xdf], axis=1)
xdf
# Out:
#        Salary  Salary in USD  Year  Job Title_AI Developer  \
# 0      138000         138000  2024                   False
# 1       86000          86000  2024                   False
# 2      179000         179000  2024                   False
# 3      112000         112000  2024                   False
# 4       92000          92000  2024                   False
# ...       ...            ...   ...                     ...
# 5731   412000         412000  2020                   False
# 5732   151000         151000  2021                   False
# 5733   105000         105000  2020                   False
# 5734   100000         100000  2020                   False
# 5735  7000000          94665  2021                   False
#
#       Job Title_AI Engineer  Job Title_AI Product Manager  \
# 0                     False                         False
# 1                     False                         False
# 2                     False                         False
# 3                     False                         False
# 4                     False                         False
# ...                     ...                           ...
# 5731                  False                         False
# 5732                  False                         False
# 5733                  False                         False
# 5734                  False                         False
# 5735                  False                         False
#
#       Job Title_AI Programmer  Job Title_AI Research Engineer  \
# 0                       False                           False
# 1                       False                           False
# 2                       False                           False
# 3                       False                           False
# 4                       False                           False
# ...                       ...                             ...
# 5731                    False                           False
# 5732                    False                           False
# 5733                    False                           False
# 5734                    False                           False
# 5735                    False                           False
#
#       Job Title_AI Scientist  Job Title_AWS Data Architect  ...  \
# 0                      False                         False  ...
# 1                      False                         False  ...
# 2                      False                         False  ...
# 3                      False                         False  ...
# 4                      False                         False  ...
# ...                      ...                           ...  ...
# 5731                   False                         False  ...
# 5732                   False                         False  ...
# 5733                   False                         False  ...
# 5734                   False                         False  ...
# 5735                   False                         False  ...
#
#       Employee Residence_Turkey  Employee Residence_Uganda  \
# 0                         False                      False
# 1                         False                      False
# 2                         False                      False
# 3                         False                      False
# 4                         False                      False
# ...                         ...                        ...
# 5731                      False                      False
# 5732                      False                      False
# 5733                      False                      False
# 5734                      False                      False
# 5735                      False                      False
#
#       Employee Residence_Ukraine  Employee Residence_United Arab Emirates  \
# 0                          False                                    False
# 1                          False                                    False
# 2                          False                                    False
# 3                          False                                    False
# 4                          False                                    False
# ...                          ...                                      ...
# 5731                       False                                    False
# 5732                       False                                    False
# 5733                       False                                    False
# 5734                       False                                    False
# 5735                       False                                    False
#
#       Employee Residence_United Kingdom  Employee Residence_United States  \
# 0                                 False                              True
# 1                                 False                              True
# 2                                 False                              True
# 3                                 False                              True
# 4                                 False                              True
# ...                                 ...                               ...
# 5731                              False                              True
# 5732                              False                              True
# 5733                              False                              True
# 5734                              False                              True
# 5735                              False                             False
#
#       Employee Residence_Uzbekistan  Employee Residence_Viet Nam  \
# 0                             False                        False
# 1                             False                        False
# 2                             False                        False
# 3                             False                        False
# 4                             False                        False
# ...                             ...                          ...
# 5731                          False                        False
# 5732                          False                        False
# 5733                          False                        False
# 5734                          False                        False
# 5735                          False                        False
#
#       Company Size_Medium  Company Size_Small
# 0                    True               False
# 1                    True               False
# 2                    True               False
# 3                    True               False
# 4                    True               False
# ...                   ...                 ...
# 5731                False               False
# 5732                False               False
# 5733                False                True
# 5734                False               False
# 5735                False               False
#
# [5736 rows x 325 columns]

# %%
y = xdf["Salary in USD"].values.ravel()
X = xdf.loc[:, "Year":]

# %%
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size = .2)

scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
alphas = np.logspace(.001, 8)/100
penalties = [.1, .5, .7, .9, .95, .99, 1]
alphas
# Out:
# array([1.00230524e-02, 1.45963712e-02, 2.12564040e-02, 3.09552769e-02,
#        4.50795520e-02, 6.56484520e-02, 9.56025305e-02, 1.39224057e-01,
#        2.02749216e-01, 2.95259637e-01, 4.29980717e-01, 6.26172337e-01,
#        9.11882278e-01, 1.32795596e+00, 1.93387577e+00, 2.81626469e+00,
#        4.10127006e+00, 5.97259774e+00, 8.69777489e+00, 1.26663960e+01,
#        1.84458197e+01, 2.68622791e+01, 3.91190010e+01, 5.69682204e+01,
#        8.29616825e+01, 1.20815443e+02, 1.75941118e+02, 2.56219539e+02,
#        3.73127401e+02, 5.43377987e+02, 7.91310519e+02, 1.15236972e+03,
#        1.67817302e+03, 2.44388988e+03, 3.55898806e+03, 5.18288328e+03,
#        7.54772949e+03, 1.09916078e+04, 1.60068591e+04, 2.33104695e+04,
#        3.39465715e+04, 4.94357146e+04, 7.19922446e+04, 1.04840869e+05,
#        1.52677665e+05, 2.22341437e+05, 3.23791397e+05, 4.71530950e+05,
#        6.86681112e+05, 1.00000000e+06])

# %%
ecv = ElasticNetCV(alphas=alphas, l1_ratio = penalties, cv=10, verbose=1, max_iter=10_000)
ecv.fit(X_train, y_train)
# Out:
# ..................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:   35.7s
# ................................................................................................../home/red/anaconda3/envs/cda_project/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4244524205.2753906, tolerance: 2055255024.2682364
#   model = cd_fast.enet_coordinate_descent_gram(
# ./home/red/anaconda3/envs/cda_project/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8161577551.587891, tolerance: 2055255024.2682364
#   model = cd_fast.enet_coordinate_descent_gram(
# ................................................/home/red/anaconda3/envs/cda_project/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3665644130.298828, tolerance: 2020718268.5496228
#   model = cd_fast.enet_coordinate_descent_gram(
# ./home/red/anaconda3/envs/cda_project/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10440370771.134766, tolerance: 2020718268.5496228
#   model = cd_fast.enet_coordinate_descent_gram(
# ./home/red/anaconda3/envs/cda_project/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14950505504.30664, tolerance: 2020718268.5496228
#   model = cd_fast.enet_coordinate_descent_gram(
# ................................................./home/red/anaconda3/envs/cda_project/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2941390879.1777344, tolerance: 1956601521.9794755
#   model = cd_fast.enet_coordinate_descent_gram(
# ./home/red/anaconda3/envs/cda_project/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4558531784.7890625, tolerance: 1956601521.9794755
#   model = cd_fast.enet_coordinate_descent_gram(
# ................................................./home/red/anaconda3/envs/cda_project/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4409883764.396484, tolerance: 2054326873.7294576
#   model = cd_fast.enet_coordinate_descent_gram(
# ./home/red/anaconda3/envs/cda_project/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5718881284.378906, tolerance: 2054326873.7294576
#   model = cd_fast.enet_coordinate_descent_gram(
# ................................................./home/red/anaconda3/envs/cda_project/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2190680498.5585938, tolerance: 2068242271.5277133
#   model = cd_fast.enet_coordinate_descent_gram(
# ./home/red/anaconda3/envs/cda_project/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2741276426.8222656, tolerance: 2068242271.5277133
#   model = cd_fast.enet_coordinate_descent_gram(
# ................................................/home/red/anaconda3/envs/cda_project/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2159993704.46875, tolerance: 2049152762.5993736
#   model = cd_fast.enet_coordinate_descent_gram(
# ./home/red/anaconda3/envs/cda_project/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5017622605.419922, tolerance: 2049152762.5993736
#   model = cd_fast.enet_coordinate_descent_gram(
# ./home/red/anaconda3/envs/cda_project/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7846209242.199219, tolerance: 2049152762.5993736
#   model = cd_fast.enet_coordinate_descent_gram(
# ................................................./home/red/anaconda3/envs/cda_project/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2765198511.109375, tolerance: 2063139451.353387
#   model = cd_fast.enet_coordinate_descent_gram(
# ./home/red/anaconda3/envs/cda_project/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4494748743.390625, tolerance: 2063139451.353387
#   model = cd_fast.enet_coordinate_descent_gram(
# ................................................./home/red/anaconda3/envs/cda_project/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3675531349.7773438, tolerance: 2085468773.3464684
#   model = cd_fast.enet_coordinate_descent_gram(
# ./home/red/anaconda3/envs/cda_project/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5053917445.134766, tolerance: 2085468773.3464684
#   model = cd_fast.enet_coordinate_descent_gram(
# ................................................/home/red/anaconda3/envs/cda_project/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2139788492.0175781, tolerance: 2035693759.2191849
#   model = cd_fast.enet_coordinate_descent_gram(
# ./home/red/anaconda3/envs/cda_project/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4969890380.425781, tolerance: 2035693759.2191849
#   model = cd_fast.enet_coordinate_descent_gram(
# ./home/red/anaconda3/envs/cda_project/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6891110113.171875, tolerance: 2035693759.2191849
#   model = cd_fast.enet_coordinate_descent_gram(
# ................................................./home/red/anaconda3/envs/cda_project/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4526025009.279297, tolerance: 2072082392.1923943
#   model = cd_fast.enet_coordinate_descent_gram(
# ./home/red/anaconda3/envs/cda_project/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5920491918.484375, tolerance: 2072082392.1923943
#   model = cd_fast.enet_coordinate_descent_gram(
# .....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# ElasticNetCV(alphas=array([1.00230524e-02, 1.45963712e-02, 2.12564040e-02, 3.09552769e-02,
#        4.50795520e-02, 6.56484520e-02, 9.56025305e-02, 1.39224057e-01,
#        2.02749216e-01, 2.95259637e-01, 4.29980717e-01, 6.26172337e-01,
#        9.11882278e-01, 1.32795596e+00, 1.93387577e+00, 2.81626469e+00,
#        4.10127006e+00, 5.97259774e+00, 8.69777489e+00, 1.26663960e+01,
#        1.84458197e+01, 2.686227...
#        3.73127401e+02, 5.43377987e+02, 7.91310519e+02, 1.15236972e+03,
#        1.67817302e+03, 2.44388988e+03, 3.55898806e+03, 5.18288328e+03,
#        7.54772949e+03, 1.09916078e+04, 1.60068591e+04, 2.33104695e+04,
#        3.39465715e+04, 4.94357146e+04, 7.19922446e+04, 1.04840869e+05,
#        1.52677665e+05, 2.22341437e+05, 3.23791397e+05, 4.71530950e+05,
#        6.86681112e+05, 1.00000000e+06]),
#              cv=10, l1_ratio=[0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1],
#              max_iter=10000, verbose=1)

# %%
y_pred = lcv.predict(X_test)
print(y_pred.shape)
display(mean_squared_error(y_pred=y_pred, y_true=y_test))
display(r2_score(y_pred=y_pred, y_true=y_test))
# Out:
# (1148,)
# 3447070448.146592
# 0.3267565399281267

# %%
print(lcv.coef_.shape, "->", (lcv.coef_ >0).sum())
# Out:
# (323,) -> 68

# %%
selected = np.argwhere(lcv.coef_>0).flatten()

# %%
selected
# Out:
# array([  0,   1,   2,   6,   7,   9,  10,  13,  20,  30,  33,  47,  50,
#         69,  70,  72,  73,  82,  84,  87,  89,  90,  91,  94,  97, 100,
#        101, 107, 108, 111, 112, 119, 120, 121, 125, 126, 128, 135, 137,
#        150, 158, 161, 172, 177, 195, 197, 199, 203, 207, 219, 222, 240,
#        247, 250, 264, 273, 275, 283, 285, 287, 299, 300, 303, 305, 310,
#        317, 318, 321])

# %%
X.iloc[:,~selected].columns
# Out:
# Index(['Company Size_Small', 'Company Size_Medium',
#        'Employee Residence_Viet Nam',
#        'Employee Residence_United Arab Emirates', 'Employee Residence_Ukraine',
#        'Employee Residence_Turkey', 'Employee Residence_Tunisia',
#        'Employee Residence_Sweden', 'Employee Residence_Russian Federation',
#        'Employee Residence_Nigeria', 'Employee Residence_Moldova, Republic of',
#        'Employee Residence_Israel',
#        'Employee Residence_Iran, Islamic Republic of',
#        'Employee Residence_Croatia', 'Employee Residence_Costa Rica',
#        'Employee Residence_China', 'Employee Residence_Chile',
#        'Employee Residence_Australia', 'Employee Residence_Argentina',
#        'Company Location_Viet Nam', 'Company Location_United Kingdom',
#        'Company Location_United Arab Emirates', 'Company Location_Ukraine',
#        'Company Location_Switzerland', 'Company Location_South Africa',
#        'Company Location_Saudi Arabia', 'Company Location_Russian Federation',
#        'Company Location_Philippines', 'Company Location_Pakistan',
#        'Company Location_New Zealand', 'Company Location_Netherlands',
#        'Company Location_Lithuania', 'Company Location_Latvia',
#        'Company Location_Korea, Republic of', 'Company Location_Israel',
#        'Company Location_Ireland',
#        'Company Location_Iran, Islamic Republic of',
#        'Company Location_Gibraltar', 'Company Location_Germany',
#        'Company Location_Canada', 'Company Location_Argentina',
#        'Salary Currency_United States Dollar',
#        'Salary Currency_Israeli New Shekel', 'Salary Currency_Danish Krone',
#        'Job Title_Sales Data Analyst', 'Job Title_Research Engineer',
#        'Job Title_Prompt Engineer', 'Job Title_Principal Data Engineer',
#        'Job Title_NLP Engineer', 'Job Title_Machine Learning Modeler',
#        'Job Title_Machine Learning Engineer',
#        'Job Title_Deep Learning Engineer', 'Job Title_Data Specialist',
#        'Job Title_Data Science Tech Lead', 'Job Title_Data Operations Manager',
#        'Job Title_Data Integration Specialist',
#        'Job Title_Data Infrastructure Engineer',
#        'Job Title_Data Analytics Engineer', 'Job Title_Data Analyst Lead',
#        'Job Title_Consultant Data Engineer',
#        'Job Title_Business Intelligence Analyst',
#        'Job Title_Business Data Analyst', 'Job Title_BI Developer',
#        'Job Title_BI Data Analyst',
#        'Job Title_Applied Machine Learning Scientist',
#        'Job Title_AI Research Engineer', 'Job Title_AI Programmer',
#        'Job Title_AI Developer'],
#       dtype='object')

# %% [markdown]
# Elastic Net Parameters
#
# {'alpha': 1.0,
#  'copy_X': True,
#  'fit_intercept': True,
#  'l1_ratio': 0.5,
#  'max_iter': 1000,
#  'positive': False,
#  'precompute': False,
#  'random_state': None,
#  'selection': 'cyclic',
#  'tol': 0.0001,
#  'warm_start': False}

# %%
search = {'alpha': [0.01, 0.1,1,10,],
          'l1_ratio'  :  np.arange(0.0, 1.00,0.10)}
